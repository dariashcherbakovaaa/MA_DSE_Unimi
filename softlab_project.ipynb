# %% [markdown]
# <a href="https://colab.research.google.com/github/dariashcherbakovaaa/MA_DSE_Unimi/blob/LABs/softlab_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
esg = pd.read_excel('/content/drive/MyDrive/softlab-lab_finalproject/ESG_WorldBank_20042023_AllCountries_transposed_EXCEL.xlsx', sheet_name= 'Sheet1')

esg.head(5)
# Out:
#   Country Name Continent Country Code  Year  \
# 0  Afghanistan      Asia          AFG  2004
# 1  Afghanistan      Asia          AFG  2005
# 2  Afghanistan      Asia          AFG  2006
# 3  Afghanistan      Asia          AFG  2007
# 4  Afghanistan      Asia          AFG  2008
#
#    Access to clean fuels and technologies for cooking (% of population)  \
# 0                                               11.1
# 1                                               12.5
# 2                                               13.9
# 3                                               15.3
# 4                                               16.8
#
#    Access to electricity (% of population)  \
# 0                                23.814182
# 1                                28.669672
# 2                                33.544418
# 3                                38.440002
# 4                                42.400000
#
#    Adjusted savings: natural resources depletion (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted savings: net forest depletion (% of GNI)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Agricultural land (% of land area)  \
# 0                           58.151266
# 1                           58.134400
# 2                           58.123668
# 3                           58.129801
# 4                           58.132867
#
#    Agriculture, forestry, and fishing, value added (% of GDP)  ...  \
# 0                                          29.721067           ...
# 1                                          31.114855           ...
# 2                                          28.635969           ...
# 3                                          30.105011           ...
# 4                                          24.892270           ...
#
#    School enrollment, primary (% gross)  \
# 0                            106.252663
# 1                            100.229691
# 2                            103.932243
# 3                            101.086456
# 4                            103.413963
#
#    School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 0                                            0.40582
# 1                                            0.54769
# 2                                            0.57323
# 3                                            0.56720
# 4                                            0.58602
#
#    Scientific and technical journal articles  \
# 0                                       6.75
# 1                                       9.15
# 2                                      14.86
# 3                                      13.23
# 4                                      12.50
#
#    Standardised Precipitation-Evapotranspiration Index  \
# 0                                          -0.711262
# 1                                           0.838650
# 2                                          -0.381402
# 3                                          -0.358944
# 4                                          -1.388464
#
#    Strength of legal rights index (0=weak to 12=strong)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Terrestrial and marine protected areas (% of total territorial area)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Tree Cover Loss (hectares)  \
# 0                       201.0
# 1                       236.0
# 2                       152.0
# 3                       253.0
# 4                       107.0
#
#    Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# 0                                              7.926
# 1                                              7.925
# 2                                              7.925
# 3                                              7.924
# 4                                              7.928
#
#    Unmet need for contraception (% of married women ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Voice and Accountability: Estimate
# 0                           -1.203034
# 1                           -1.125430
# 2                           -1.110294
# 3                           -1.057654
# 4                           -1.168902
#
# [5 rows x 75 columns]

# %%
metadf = pd.read_excel('/content/drive/MyDrive/softlab-lab_finalproject/Metadata.xlsx', sheet_name= "Series - Metadata")
print(f'The shape is {metadf.shape}\n\n')
metadf.head(6)
# Out:
# The shape is (71, 20)
#                 Code License Type  \
# 0     EG.CFT.ACCS.ZS    CC BY-4.0
# 1     EG.ELC.ACCS.ZS    CC BY-4.0
# 2  NY.ADJ.DRES.GN.ZS    CC BY-4.0
# 3  NY.ADJ.DFOR.GN.ZS    CC BY-4.0
# 4     AG.LND.AGRI.ZS    CC BY-4.0
# 5     NV.AGR.TOTL.ZS    CC BY-4.0
#
#                                       Indicator Name Short definition  \
# 0  Access to clean fuels and technologies for coo...              NaN
# 1            Access to electricity (% of population)              NaN
# 2  Adjusted savings: natural resources depletion ...              NaN
# 3  Adjusted savings: net forest depletion (% of GNI)              NaN
# 4                 Agricultural land (% of land area)              NaN
# 5  Agriculture, forestry, and fishing, value adde...              NaN
#
#                                      Long definition  \
# 0  Access to clean fuels and technologies for coo...
# 1  Access to electricity is the percentage of pop...
# 2  Natural resource depletion is the sum of net f...
# 3  Net forest depletion is calculated as the prod...
# 4  Agricultural land refers to the share of land ...
# 5  Agriculture, forestry, and fishing corresponds...
#
#                                               Source  \
# 0  IEA, IRENA, UNSD, World Bank, WHO. 2023. Track...
# 1  IEA, IRENA, UNSD, World Bank, WHO. 2023. Track...
# 2  World Bank staff estimates based on sources an...
# 3  World Bank staff estimates based on sources an...
# 4  Food and Agriculture Organization, electronic ...
# 5  World Bank national accounts data, and OECD Na...
#
#                                                Topic Unit of measure  \
# 0                         Social: Access to Services             NaN
# 1                         Social: Access to Services             NaN
# 2  Environment: Natural capital endowment and man...             NaN
# 3  Environment: Natural capital endowment and man...             NaN
# 4                         Environment: Food Security             NaN
# 5                         Environment: Food Security             NaN
#
#   Periodicity Base Period Aggregation method  \
# 0      Annual         NaN   Weighted average
# 1      Annual         NaN   Weighted average
# 2      Annual         NaN   Weighted average
# 3      Annual         NaN   Weighted average
# 4      Annual         NaN   Weighted average
# 5      Annual         NaN   Weighted average
#
#                  Statistical concept and methodology  \
# 0  Data for access to clean fuels and technologie...
# 1  The World Bank’s Global Electrification Databa...
# 2  Natural resources depletion is the sum of net ...
# 3                                                NaN
# 4  Agriculture is still a major sector in many ec...
# 5  Gross domestic product (GDP) represents the su...
#
#                                Development relevance  \
# 0                                                NaN
# 1  Maintaining reliable and secure electricity se...
# 2  Natural resources depletion is a critical comp...
# 3                                                NaN
# 4  Agricultural land covers more than one-third o...
# 5                                                NaN
#
#                           Limitations and exceptions  \
# 0                                                NaN
# 1                                                NaN
# 2  Net forest depletion is not the monetary value...
# 3  A positive net depletion figure for forest res...
# 4  The data are collected by the Food and Agricul...
# 5  Among the difficulties faced by compilers of n...
#
#                                     General comments  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Note: Data for OECD countries are based on ISI...
#
#                                          Other notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Areas of former states are included in the suc...
# 5                                                NaN
#
#   Notes from original source Related source links Other web links  \
# 0                        NaN                  NaN             NaN
# 1                        NaN                  NaN             NaN
# 2                        NaN                  NaN             NaN
# 3                        NaN                  NaN             NaN
# 4                        NaN                  NaN             NaN
# 5                        NaN                  NaN             NaN
#
#                                          License URL
# 0  https://datacatalog.worldbank.org/public-licen...
# 1  https://datacatalog.worldbank.org/public-licen...
# 2  https://datacatalog.worldbank.org/public-licen...
# 3  https://datacatalog.worldbank.org/public-licen...
# 4  https://datacatalog.worldbank.org/public-licen...
# 5  https://datacatalog.worldbank.org/public-licen...

# %%
metadf['Topic'] = metadf['Topic'].fillna('Environment')
metadf[metadf['Topic'].isna()].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
import re

pattern_environment = r'\benvironment:\w*'


meta_env = metadf[metadf['Topic'].str.contains(pattern_environment, flags=re.IGNORECASE)]

print(f'The shape is {meta_env.shape}\n\n')
meta_env.head(6)
# Out:
# The shape is (30, 20)
#                  Code                                       License Type  \
# 2   NY.ADJ.DRES.GN.ZS                                          CC BY-4.0
# 3   NY.ADJ.DFOR.GN.ZS                                          CC BY-4.0
# 4      AG.LND.AGRI.ZS                                          CC BY-4.0
# 5      NV.AGR.TOTL.ZS                                          CC BY-4.0
# 6      ER.H2O.FWTL.ZS                                          CC BY-4.0
# 10     EN.ATM.CO2E.PC  Attribution-NonCommercial 4.0 International (C...
#
#                                        Indicator Name Short definition  \
# 2   Adjusted savings: natural resources depletion ...              NaN
# 3   Adjusted savings: net forest depletion (% of GNI)              NaN
# 4                  Agricultural land (% of land area)              NaN
# 5   Agriculture, forestry, and fishing, value adde...              NaN
# 6   Annual freshwater withdrawals, total (% of int...              NaN
# 10             CO2 emissions (metric tons per capita)              NaN
#
#                                       Long definition  \
# 2   Natural resource depletion is the sum of net f...
# 3   Net forest depletion is calculated as the prod...
# 4   Agricultural land refers to the share of land ...
# 5   Agriculture, forestry, and fishing corresponds...
# 6   Annual freshwater withdrawals refer to total w...
# 10  Carbon dioxide emissions are those stemming fr...
#
#                                                Source  \
# 2   World Bank staff estimates based on sources an...
# 3   World Bank staff estimates based on sources an...
# 4   Food and Agriculture Organization, electronic ...
# 5   World Bank national accounts data, and OECD Na...
# 6   Food and Agriculture Organization, AQUASTAT data.
# 10  Emissions data are sourced from Climate Watch ...
#
#                                                 Topic Unit of measure  \
# 2   Environment: Natural capital endowment and man...             NaN
# 3   Environment: Natural capital endowment and man...             NaN
# 4                          Environment: Food Security             NaN
# 5                          Environment: Food Security             NaN
# 6   Environment: Natural capital endowment and man...             NaN
# 10                 Environment: Emissions & pollution             NaN
#
#    Periodicity Base Period Aggregation method  \
# 2       Annual         NaN   Weighted average
# 3       Annual         NaN   Weighted average
# 4       Annual         NaN   Weighted average
# 5       Annual         NaN   Weighted average
# 6       Annual         NaN   Weighted average
# 10      Annual         NaN   Weighted average
#
#                   Statistical concept and methodology  \
# 2   Natural resources depletion is the sum of net ...
# 3                                                 NaN
# 4   Agriculture is still a major sector in many ec...
# 5   Gross domestic product (GDP) represents the su...
# 6   Annual freshwater withdrawals are total water ...
# 10  Carbon dioxide emissions, largely by-products ...
#
#                                 Development relevance  \
# 2   Natural resources depletion is a critical comp...
# 3                                                 NaN
# 4   Agricultural land covers more than one-third o...
# 5                                                 NaN
# 6   While some countries have an abundant supply o...
# 10  Carbon dioxide (CO2) is naturally occurring ga...
#
#                            Limitations and exceptions  \
# 2   Net forest depletion is not the monetary value...
# 3   A positive net depletion figure for forest res...
# 4   The data are collected by the Food and Agricul...
# 5   Among the difficulties faced by compilers of n...
# 6   A common perception is that most of the availa...
# 10                                                NaN
#
#                                      General comments  \
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Note: Data for OECD countries are based on ISI...
# 6                                                 NaN
# 10                                                NaN
#
#                                           Other notes  \
# 2                                                 NaN
# 3                                                 NaN
# 4   Areas of former states are included in the suc...
# 5                                                 NaN
# 6                                                 NaN
# 10                                                NaN
#
#    Notes from original source Related source links Other web links  \
# 2                         NaN                  NaN             NaN
# 3                         NaN                  NaN             NaN
# 4                         NaN                  NaN             NaN
# 5                         NaN                  NaN             NaN
# 6                         NaN                  NaN             NaN
# 10                        NaN                  NaN             NaN
#
#                                           License URL
# 2   https://datacatalog.worldbank.org/public-licen...
# 3   https://datacatalog.worldbank.org/public-licen...
# 4   https://datacatalog.worldbank.org/public-licen...
# 5   https://datacatalog.worldbank.org/public-licen...
# 6   https://datacatalog.worldbank.org/public-licen...
# 10    https://creativecommons.org/licenses/by-nc/4.0/

# %%
meta_env.Topic.unique()
# Out:
# array(['Environment: Natural capital endowment and management',
#        'Environment: Food Security', 'Environment: Emissions & pollution',
#        'Environment: Environment/climate risk & resilience',
#        'Environment: Energy use & security'], dtype=object)

# %%
print(meta_env['Indicator Name'].value_counts())
indicators_list = meta_env['Indicator Name'].unique()
# Out:
# Indicator Name
# Adjusted savings: natural resources depletion (% of GNI)                  1
# Adjusted savings: net forest depletion (% of GNI)                         1
# Terrestrial and marine protected areas (% of total territorial area)      1
# Standardised Precipitation-Evapotranspiration Index                       1
# Renewable energy consumption (% of total final energy consumption)        1
# Renewable electricity output (% of total electricity output)              1
# Proportion of bodies of water with good ambient water quality             1
# Population density (people per sq. km of land area)                       1
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)    1
# Nitrous oxide emissions (metric tons of CO2 equivalent per capita)        1
# Methane emissions (metric tons of CO2 equivalent per capita)              1
# Mammal species, threatened                                                1
# Land Surface Temperature                                                  1
# Heating Degree Days                                                       1
# Heat Index 35                                                             1
# GHG net emissions/removals by LUCF (Mt of CO2 equivalent)                 1
# Fossil fuel energy consumption (% of total)                               1
# Forest area (% of land area)                                              1
# Food production index (2014-2016 = 100)                                   1
# Energy use (kg of oil equivalent per capita)                              1
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)               1
# Energy imports, net (% of energy use)                                     1
# Electricity production from coal sources (% of total)                     1
# Cooling Degree Days                                                       1
# Coastal protection                                                        1
# CO2 emissions (metric tons per capita)                                    1
# Annual freshwater withdrawals, total (% of internal resources)            1
# Agriculture, forestry, and fishing, value added (% of GDP)                1
# Agricultural land (% of land area)                                        1
# Tree Cover Loss                                                           1
# Name: count, dtype: int64

# %%
esg.columns.values.tolist()
# Out:
# ['Country Name',
#  'Continent',
#  'Country Code',
#  'Year',
#  'Access to clean fuels and technologies for cooking (% of population)',
#  'Access to electricity (% of population)',
#  'Adjusted savings: natural resources depletion (% of GNI)',
#  'Adjusted savings: net forest depletion (% of GNI)',
#  'Agricultural land (% of land area)',
#  'Agriculture, forestry, and fishing, value added (% of GDP)',
#  'Annual freshwater withdrawals, total (% of internal resources)',
#  'Annualized average growth rate in per capita real survey mean consumption or income, total population (%)',
#  'CO2 emissions (metric tons per capita)',
#  'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
#  'Children in employment, total (% of children ages 7-14)',
#  'Coastal protection',
#  'Control of Corruption: Estimate',
#  'Cooling Degree Days',
#  'Economic and Social Rights Performance Score',
#  'Electricity production from coal sources (% of total)',
#  'Energy imports, net (% of energy use)',
#  'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#  'Energy use (kg of oil equivalent per capita)',
#  'Fertility rate, total (births per woman)',
#  'Food production index (2014-2016 = 100)',
#  'Forest area (% of land area)',
#  'Fossil fuel energy consumption (% of total)',
#  'GDP growth (annual %)',
#  'GHG net emissions/removals by LUCF (Mt of CO2 equivalent)',
#  'Gini index',
#  'Government Effectiveness: Estimate',
#  'Government expenditure on education, total (% of government expenditure)',
#  'Heat Index 35',
#  'Heating Degree Days',
#  'Hospital beds (per 1,000 people)',
#  'Income share held by lowest 20%',
#  'Individuals using the Internet (% of population)',
#  'Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#  'Land Surface Temperature',
#  'Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
#  'Life expectancy at birth, total (years)',
#  'Literacy rate, adult total (% of people ages 15 and above)',
#  'Mammal species, threatened',
#  'Methane emissions (metric tons of CO2 equivalent per capita)',
#  'Mortality rate, under-5 (per 1,000 live births)',
#  'Net migration',
#  'Nitrous oxide emissions (metric tons of CO2 equivalent per capita)',
#  'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#  'Patent applications, residents',
#  'People using safely managed drinking water services (% of population)',
#  'People using safely managed sanitation services (% of population)',
#  'Political Stability and Absence of Violence/Terrorism: Estimate',
#  'Population ages 65 and above (% of total population)',
#  'Population density (people per sq. km of land area)',
#  'Poverty headcount ratio at national poverty lines (% of population)',
#  'Prevalence of overweight (% of adults)',
#  'Prevalence of undernourishment (% of population)',
#  'Proportion of bodies of water with good ambient water quality',
#  'Proportion of seats held by women in national parliaments (%)',
#  'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#  'Regulatory Quality: Estimate',
#  'Renewable electricity output (% of total electricity output)',
#  'Renewable energy consumption (% of total final energy consumption)',
#  'Research and development expenditure (% of GDP)',
#  'Rule of Law: Estimate',
#  'School enrollment, primary (% gross)',
#  'School enrollment, primary and secondary (gross), gender parity index (GPI)',
#  'Scientific and technical journal articles',
#  'Standardised Precipitation-Evapotranspiration Index',
#  'Strength of legal rights index (0=weak to 12=strong)',
#  'Terrestrial and marine protected areas (% of total territorial area)',
#  'Tree Cover Loss (hectares)',
#  'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#  'Unmet need for contraception (% of married women ages 15-49)',
#  'Voice and Accountability: Estimate']

# %%
relevant_columns = ["Country Name", 'Continent', "Year"] + [col for col in esg.columns if col in indicators_list]
esg_env = esg[relevant_columns]

# %%
esg_env
# Out:
#      Country Name Continent  Year  \
# 0     Afghanistan      Asia  2004
# 1     Afghanistan      Asia  2005
# 2     Afghanistan      Asia  2006
# 3     Afghanistan      Asia  2007
# 4     Afghanistan      Asia  2008
# ...           ...       ...   ...
# 3815     Zimbabwe    Africa  2019
# 3816     Zimbabwe    Africa  2020
# 3817     Zimbabwe    Africa  2021
# 3818     Zimbabwe    Africa  2022
# 3819     Zimbabwe    Africa  2023
#
#       Adjusted savings: natural resources depletion (% of GNI)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3815                                           4.088445
# 3816                                           4.108902
# 3817                                           5.053145
# 3818                                                NaN
# 3819                                                NaN
#
#       Adjusted savings: net forest depletion (% of GNI)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3815                                           2.028044
# 3816                                           2.315889
# 3817                                           1.865862
# 3818                                                NaN
# 3819                                                NaN
#
#       Agricultural land (% of land area)  \
# 0                              58.151266
# 1                              58.134400
# 2                              58.123668
# 3                              58.129801
# 4                              58.132867
# ...                                  ...
# 3815                           41.876696
# 3816                           41.876696
# 3817                           41.876696
# 3818                                 NaN
# 3819                                 NaN
#
#       Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0                                             29.721067
# 1                                             31.114855
# 2                                             28.635969
# 3                                             30.105011
# 4                                             24.892270
# ...                                                 ...
# 3815                                           9.819262
# 3816                                           8.772859
# 3817                                           8.849899
# 3818                                           7.191922
# 3819                                                NaN
#
#       Annual freshwater withdrawals, total (% of internal resources)  \
# 0                                             43.015907
# 1                                             43.015907
# 2                                             43.015907
# 3                                             43.015907
# 4                                             43.015907
# ...                                                 ...
# 3815                                          30.761677
# 3816                                          30.761677
# 3817                                                NaN
# 3818                                                NaN
# 3819                                                NaN
#
#       CO2 emissions (metric tons per capita)  Coastal protection  ...  \
# 0                                   0.054867                 NaN  ...
# 1                                   0.080361                 NaN  ...
# 2                                   0.089757                 NaN  ...
# 3                                   0.109940                 NaN  ...
# 4                                   0.165573                 NaN  ...
# ...                                      ...                 ...  ...
# 3815                                0.663338                 NaN  ...
# 3816                                0.530484                 NaN  ...
# 3817                                     NaN                 NaN  ...
# 3818                                     NaN                 NaN  ...
# 3819                                     NaN                 NaN  ...
#
#       Mammal species, threatened  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 3815                         NaN
# 3816                         NaN
# 3817                         NaN
# 3818                         NaN
# 3819                         NaN
#
#       Methane emissions (metric tons of CO2 equivalent per capita)  \
# 0                                              0.445806
# 1                                              0.439623
# 2                                              0.439260
# 3                                              0.448224
# 4                                              0.488320
# ...                                                 ...
# 3815                                           0.811302
# 3816                                           0.769692
# 3817                                                NaN
# 3818                                                NaN
# 3819                                                NaN
#
#       Nitrous oxide emissions (metric tons of CO2 equivalent per capita)  \
# 0                                              0.155651
# 1                                              0.156612
# 2                                              0.143932
# 3                                              0.138788
# 4                                              0.146819
# ...                                                 ...
# 3815                                           0.338353
# 3816                                           0.299359
# 3817                                                NaN
# 3818                                                NaN
# 3819                                                NaN
#
#       PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                   NaN
# 1                                             46.151929
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3815                                          20.834700
# 3816                                                NaN
# 3817                                                NaN
# 3818                                                NaN
# 3819                                                NaN
#
#       Population density (people per sq. km of land area)  \
# 0                                             36.112339
# 1                                             37.427274
# 2                                             39.009159
# 3                                             39.714979
# 4                                             40.518221
# ...                                                 ...
# 3815                                          39.691374
# 3816                                          40.505793
# 3817                                          41.342960
# 3818                                                NaN
# 3819                                                NaN
#
#       Proportion of bodies of water with good ambient water quality  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3815                                                NaN
# 3816                                               83.3
# 3817                                                NaN
# 3818                                                NaN
# 3819                                                NaN
#
#       Renewable electricity output (% of total electricity output)  \
# 0                                             70.890841
# 1                                             74.061810
# 2                                             70.755750
# 3                                             72.000000
# 4                                             68.654822
# ...                                                 ...
# 3815                                                NaN
# 3816                                                NaN
# 3817                                                NaN
# 3818                                                NaN
# 3819                                                NaN
#
#       Renewable energy consumption (% of total final energy consumption)  \
# 0                                                 44.24
# 1                                                 33.88
# 2                                                 31.89
# 3                                                 28.78
# 4                                                 21.17
# ...                                                 ...
# 3815                                              81.52
# 3816                                              84.36
# 3817                                                NaN
# 3818                                                NaN
# 3819                                                NaN
#
#       Standardised Precipitation-Evapotranspiration Index  \
# 0                                             -0.711262
# 1                                              0.838650
# 2                                             -0.381402
# 3                                             -0.358944
# 4                                             -1.388464
# ...                                                 ...
# 3815                                          -0.301619
# 3816                                          -0.204054
# 3817                                          -0.549090
# 3818                                                NaN
# 3819                                                NaN
#
#       Terrestrial and marine protected areas (% of total territorial area)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3815                                          27.214747
# 3816                                          27.214747
# 3817                                          27.214747
# 3818                                          27.214747
# 3819                                                NaN
#
# [3820 rows x 32 columns]
